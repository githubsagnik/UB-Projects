# %% [markdown]
# ### Sagnik Ghosh
# ### UbitName : sagnikgh
# ### Person Number : 50289151

# %% [markdown]
# ### Teammate :
# ### Apurba Mahanta
# ### UbitName : apurbama
# ### Person Number : 50288705

# %%
## install devtools package if it's not already
#if (!requireNamespace("devtools", quietly = TRUE)) {
#  install.packages("devtools")
#}

## install dev version of rtweet from github
#devtools::install_github("mkearney/rtweet")

## load rtweet package
library(rtweet)

# %%
## access token method: create token and save it as an environment variable
twitter_token <- create_token(app = "DIC Spring - 2019",
                              consumer_key = "Iu9XwB336Rh3BlqXDfvIWw8LK",
                              consumer_secret = "RQjdRGS22Bfmg3ru462ISjC3lLoYtap6X1HoKmyTdttR1EU7V2",
                              access_token = "1098702639821451266-SH9cgv7D46of7ZhLLZiUtkfLtnTvVw",
                              access_secret = "9X04POoNBEJ4Wu1dlwKmHhQhDikKmXpvsVKUyeNADKjaL")

# %%
library(rtweet)
## authenticate via access token
#install.packages("revgeo")
library(revgeo)
library("ggmap")
register_google(key = "AIzaSyDj9GaHg6Mzh30kGImeKR5E59zQDqdVXO4")

# %%
## search for 1000 tweets using the flu hashtag
sinceDate <- "2019-01-01"

rt <- read.csv("C:/Users/sagni/Box Sync/UB/Data Intensive Computing/Lab1/Part 3/tweets_collected_0302_#Flu#Influenza#Illness.csv")
dim(rt)
# rt
#rt$location



geocodes <- geocode(as.character(rt$Location))

tweets_collected = cbind(rt, geocodes)
tweets_path = file.path("C:", "Users", "sagni", "Box Sync", "UB", "Data Intensive Computing", "Lab1", "Part 3", "#flu#influenza#illness.csv")
save_as_csv(tweets_collected, tweets_path)
# Out:
# [1] 4106    4
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Peru,+IL&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Illinois,+USA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Bethesda,+MD&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Spartanburg,+SC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=US&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Baton+Rouge,+LA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Pennsylvania,+USA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=La+Jolla,+CA.+USA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=In+the+coop&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Columbus,+OH&key=xxx
# ...

# %%
tweet_loc_data = read_twitter_csv(tweets_path, unflatten = FALSE)



tweet_state = NULL
for (row in 1:nrow(geocodes)) {
    latlong = revgeo(longitude=geocodes[row, 1], latitude=geocodes[row, 2], provider = 'photon', output='frame')
    tweet_state = rbind(tweet_state, latlong)
}


final_data = cbind(tweet_loc_data, tweet_state$state)
final_data_path = file.path("C:", "Users", "sagni", "Box Sync", "UB","Data Intensive Computing", "Lab1", "Part 3","#flu#influenza#illness.csv")
save_as_csv(final_data, final_data_path)

# %%
fluData = read.csv("#flu#influenza#illness.csv")

# %%
library(plyr)
fluData <- fluData[!duplicated(fluData), ]
#count(data.frame(flushotData$ID), "flushotData$ID")

# %% [markdown]
# ## Number of distinct tweets for #Flu, #Influenza, #Illness, #Flushot, #Fluseason

# %%
dim(fluData)
# Out:
# [1] 2191    7

# %%
fluDataStates <-  data.frame(fluData$tweet_state.state)

#flushotDataStates

w = table(fluDataStates$fluData.tweet_state.state)
t = as.data.frame(w)
p <- data.frame(t)

#finalDF = count(flushotDataStates, "flushotData.tweet_state.state")
#finalDF

#x[,-1] <-round(x[,-1],0)
names(p)[names(p) == 'Var1'] <- 'state'

#names(x)[names(x) == 'x'] <- 'ACTIVITY.LEVEL'

# %%
state_list = list("Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming")

finalDF1 = subset(p, state!="State Not Found")
finalDF1 = subset(p, state %in% state_list)
finalDF1_path = file.path("C:", "Users", "sagni", "Box Sync", "UB","Data Intensive Computing", "Lab1", "Part 3","finalDF1.csv")
save_as_csv(finalDF1, finalDF1_path)

# %%
#flushotDataStates <-  data.frame(flushotData$tweet_state.state,flushotData$ID)

#flushotDataStates

#finalDF = count(flushotDataStates, "flushotData.tweet_state.state")

#x[,-1] <-round(x[,-1],0)
#names(x)[names(x) == 'Group.1'] <- 'state'
#names(x)[names(x) == 'x'] <- 'ACTIVITY.LEVEL'

# %%
#names(finalDF)[names(finalDF) == 'flushotDataStates.flushotData.tweet_state.state'] <- 'state'

# %%
#finalDF = subset(finalDF, state!="State Not Found")

# %%
library(usmap)
library(ggplot2)

finalDF1 = read.csv("finalDF1.csv")

cols = c("Level 10 High" = "firebrick4","Level 9 High" ="firebrick1","Level 8 High" ="orange",
         "Level 7 Moderate" ="goldenrod3","Level 6 Moderate" ="yellow","Level 5 Low" ="darkolivegreen1",
         "Level 4 Low" ="darkolivegreen4","Level 3 Minimal" ="chartreuse",
         "Level 2 Minimal" ="chartreuse3","Level 1 Minimal" ="chartreuse4")

p1 <- plot_usmap(data = finalDF1, values = "Freq", labels = FALSE)+
 scale_fill_continuous(name = "Number of Tweets",low ='green',high='red') + 
  theme(legend.position = "right") + labs(title = "Twitter Data")
p1
# Out:
# plot without title

# %%
## search for 1000 tweets using the flu hashtag

rt <- read.csv("C:/Users/sagni/Box Sync/UB/Data Intensive Computing/Lab1/Part 3/tweets_collected_0306_#Flushot.csv")
dim(rt)
# rt
#rt$location

library("ggmap")
register_google(key = "AIzaSyDj9GaHg6Mzh30kGImeKR5E59zQDqdVXO4")

geocodes <- geocode(as.character(rt$Location))

tweets_collected = cbind(rt, geocodes)
tweets_path = file.path("C:", "Users", "sagni", "Box Sync", "UB","Data Intensive Computing", "Lab1", "Part 3","#flushot.csv")
save_as_csv(tweets_collected, tweets_path)
# Out:
# [1] 224   4
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Calgary,+Alberta&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Bronx,+New+York&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Minnesota,+Florida,+Arizona&key=xxx
# "Minnesota, Florid..." not uniquely geocoded, using "florida township, mn 56220, usa"
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Seattle,+WA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Saint+Louis&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Atlanta,+GA&key=xxx
# ...

# %%
tweet_loc_data = read_twitter_csv(tweets_path, unflatten = FALSE)

tweet_state = NULL
for (row in 1:nrow(geocodes)) {
    latlong = revgeo(longitude=geocodes[row, 1], latitude=geocodes[row, 2], provider = 'photon', output='frame')
    tweet_state = rbind(tweet_state, latlong)
}

final_data = cbind(tweet_loc_data, tweet_state$state)
final_data_path = file.path("C:", "Users", "sagni", "Box Sync", "UB","Data Intensive Computing", "Lab1", "Part 3","#flushot.csv")
save_as_csv(final_data, final_data_path)
# Out:
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-114.0708459&lat=51.0486151"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-73.8648268&lat=40.8447819"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-96.3864428&lat=44.7656804"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-122.3320708&lat=47.6062095"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-90.1994042&lat=38.6270025"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-84.3879824&lat=33.7489954"
# ...

# %%
flushotData = read.csv("#flushot.csv")

# %%
library(plyr)
flushotData <- flushotData[!duplicated(flushotData), ]
#count(data.frame(flushotData$ID), "flushotData$ID")

# %% [markdown]
# ## Number of distinct tweets for #Flushot

# %%
dim(flushotData)
# Out:
# [1] 181   7

# %%
flushotDataStates <-  data.frame(flushotData$tweet_state.state)

#flushotDataStates

w = table(flushotDataStates$flushotData.tweet_state.state)
t = as.data.frame(w)
p <- data.frame(t)

#finalDF = count(flushotDataStates, "flushotData.tweet_state.state")
#finalDF

#x[,-1] <-round(x[,-1],0)
names(p)[names(p) == 'Var1'] <- 'state'
#names(x)[names(x) == 'x'] <- 'ACTIVITY.LEVEL'

# %%
state_list = list("Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming")

finalDF2 = subset(p, state!="State Not Found")
finalDF2 = subset(p, state %in% state_list)

# %%
library(usmap)
library(ggplot2)

cols = c("Level 10 High" = "firebrick4","Level 9 High" ="firebrick1","Level 8 High" ="orange",
         "Level 7 Moderate" ="goldenrod3","Level 6 Moderate" ="yellow","Level 5 Low" ="darkolivegreen1",
         "Level 4 Low" ="darkolivegreen4","Level 3 Minimal" ="chartreuse",
         "Level 2 Minimal" ="chartreuse3","Level 1 Minimal" ="chartreuse4")

p5 <- plot_usmap(data = finalDF2, values = "Freq", labels = FALSE)+
 scale_fill_continuous(name = "Number of Tweets",low ='green',high='red') + 
  theme(legend.position = "right") + labs(title = "#Flushot")
p5
# Out:
# Warning message:
# "package 'usmap' was built under R version 3.5.2"
# plot without title

# %%
## search for 1000 tweets using the flu hashtag

rt <- read.csv("C:/Users/sagni/Box Sync/UB/Data Intensive Computing/Lab1/Part 3/tweets_collected_0305_#Flueason.csv")
dim(rt)
# rt
#rt$location

library("ggmap")
register_google(key = "AIzaSyDj9GaHg6Mzh30kGImeKR5E59zQDqdVXO4")

geocodes <- geocode(as.character(rt$Location))

tweets_collected = cbind(rt, geocodes)
tweets_path = file.path("C:", "Users", "sagni", "Box Sync", "UB","Data Intensive Computing", "Lab1", "Part 3","#fluseason.csv")
save_as_csv(tweets_collected, tweets_path)
# Out:
# [1] 203   4
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=La+Vista,+NE&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=New+York,+NY&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Los+Angeles,+CA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=East+TX&key=xxx
# Warning message:
# "Geocoding "East TX" failed with error:
#
# "Source : https://maps.googleapis.com/maps/api/geocode/json?address=Knoxville,+TN&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Atlanta,+GA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Florida&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Mesa,+AZ&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Pleasanton,+CA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Houston,+TX&key=xxx
# ...

# %%
tweet_loc_data = read_twitter_csv(tweets_path, unflatten = FALSE)

tweet_state = NULL
for (row in 1:nrow(geocodes)) {
    latlong = revgeo(longitude=geocodes[row, 1], latitude=geocodes[row, 2], provider = 'photon', output='frame')
    tweet_state = rbind(tweet_state, latlong)
}

final_data = cbind(tweet_loc_data, tweet_state$state)
final_data_path = file.path("C:", "Users", "sagni", "Box Sync", "UB","Data Intensive Computing", "Lab1", "Part 3","#fluseason.csv")
save_as_csv(final_data, final_data_path)
# Out:
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-96.031127&lat=41.1838878"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-74.0059728&lat=40.7127753"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-118.2436849&lat=34.0522342"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=NA&lat=NA"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-83.9207392&lat=35.9606384"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-84.3879824&lat=33.7489954"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-81.5157535&lat=27.6648274"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-111.8314724&lat=33.4151843"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-121.8746789&lat=37.6624312"
# ...

# %%
fluseasonData = read.csv("#fluseason.csv")

# %%
library(plyr)
fluseasonData <- fluseasonData[!duplicated(fluseasonData), ]
#count(data.frame(flushotData$ID), "flushotData$ID")

# %% [markdown]
# ## Number of distinct tweets for #Fluseason

# %%
dim(fluseasonData)
# Out:
# [1] 203   7

# %%
fluseasonDataState <-  data.frame(fluseasonData$tweet_state.state)

#flushotDataStates

w = table(fluseasonDataState$fluseasonData.tweet_state.state)
t = as.data.frame(w)
p <- data.frame(t)

#finalDF = count(flushotDataStates, "flushotData.tweet_state.state")
#finalDF

#x[,-1] <-round(x[,-1],0)
names(p)[names(p) == 'Var1'] <- 'state'

#names(x)[names(x) == 'x'] <- 'ACTIVITY.LEVEL'

# %%
state_list = list("Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming")

#finalDF3 = subset(p, state!="State Not Found")
finalDF3 = subset(p, state %in% state_list)

# %%
library(usmap)
library(ggplot2)

cols = c("Level 10 High" = "firebrick4","Level 9 High" ="firebrick1","Level 8 High" ="orange",
         "Level 7 Moderate" ="goldenrod3","Level 6 Moderate" ="yellow","Level 5 Low" ="darkolivegreen1",
         "Level 4 Low" ="darkolivegreen4","Level 3 Minimal" ="chartreuse",
         "Level 2 Minimal" ="chartreuse3","Level 1 Minimal" ="chartreuse4")

p4 <- plot_usmap(data = finalDF3, values = "Freq", labels = FALSE)+
 scale_fill_continuous(name = "Number of Tweets",low ='green',high='red') + 
  theme(legend.position = "right") + labs(title = "#Fluseason")
p4
# Out:
# plot without title

# %%
## search for 1000 tweets using the flu hashtag

rt <- read.csv("C:/Users/sagni/Box Sync/UB/Data Intensive Computing/Lab1/Part 3/tweets_collected_0307_#influenza.csv")

# rt
#rt$location

library("ggmap")
register_google(key = "AIzaSyDj9GaHg6Mzh30kGImeKR5E59zQDqdVXO4")

geocodes <- geocode(as.character(rt$Location))

tweets_collected = cbind(rt, geocodes)
tweets_path = file.path("C:", "Users", "sagni", "Box Sync", "UB","Data Intensive Computing", "Lab1", "Part 3","#influenza.csv")
save_as_csv(tweets_collected, tweets_path)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Boston,+MA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Boston,+MA,+USA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Edmonton,+Canada&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Tallahassee,+FL&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=United+States&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Boston,+MA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Australia&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Des+Moines,+IA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Victoria,+Aus&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Atlanta,+GA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Madison,+WI&key=xxx
# ...

# %%
tweet_loc_data = read_twitter_csv(tweets_path, unflatten = FALSE)

tweet_state = NULL
for (row in 1:nrow(geocodes)) {
    latlong = revgeo(longitude=geocodes[row, 1], latitude=geocodes[row, 2], provider = 'photon', output='frame')
    tweet_state = rbind(tweet_state, latlong)
}

final_data = cbind(tweet_loc_data, tweet_state$state)
final_data_path = file.path("C:", "Users", "sagni", "Box Sync", "UB","Data Intensive Computing", "Lab1", "Part 3","#influenza.csv")
save_as_csv(final_data, final_data_path)
# Out:
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-71.0588801&lat=42.3600825"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-71.0588801&lat=42.3600825"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-113.4909267&lat=53.544389"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-84.2807329&lat=30.4382559"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-95.712891&lat=37.09024"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-71.0588801&lat=42.3600825"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=133.775136&lat=-25.274398"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-93.6249593&lat=41.5868353"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=144.7851531&lat=-37.4713077"
# ...

# %%
influenzaData = read.csv("#influenza.csv")

# %%
library(plyr)
influenzaData <- influenzaData[!duplicated(influenzaData), ]
#count(data.frame(flushotData$ID), "flushotData$ID")

# %% [markdown]
# ## Number of distinct tweets for #Influenza

# %%
dim(influenzaData)
# Out:
# [1] 240   7

# %%
influenzaDataState <-  data.frame(influenzaData$tweet_state.state)

#flushotDataStates

w = table(influenzaDataState$influenzaData.tweet_state.state)
t = as.data.frame(w)
p <- data.frame(t)

#finalDF = count(flushotDataStates, "flushotData.tweet_state.state")
#finalDF

#x[,-1] <-round(x[,-1],0)
names(p)[names(p) == 'Var1'] <- 'state'
#names(x)[names(x) == 'x'] <- 'ACTIVITY.LEVEL'

# %%
state_list = list("Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming")

#finalDF3 = subset(p, state!="State Not Found")
finalDF4 = subset(p, state %in% state_list)

# %%
library(usmap)
library(ggplot2)

cols = c("Level 10 High" = "firebrick4","Level 9 High" ="firebrick1","Level 8 High" ="orange",
         "Level 7 Moderate" ="goldenrod3","Level 6 Moderate" ="yellow","Level 5 Low" ="darkolivegreen1",
         "Level 4 Low" ="darkolivegreen4","Level 3 Minimal" ="chartreuse",
         "Level 2 Minimal" ="chartreuse3","Level 1 Minimal" ="chartreuse4")

p3 <- plot_usmap(data = finalDF4, values = "Freq", labels = FALSE)+
 scale_fill_continuous(name = "Number of Tweets",low ='green',high='red') + 
  theme(legend.position = "right") + labs(title = "#Influenza")
p3
# Out:
# plot without title

# %% [markdown]
# # CDC vs TWITTER data analysis:

# %% [markdown]
# ## The following are the observations made by analyzing CDC and twitter data:
# #### 1. ILI activit is on the  higher side in the south and the south-eastern states of USA.
# #### 2. For the state of Texas and Oregon, our analysis agrees with the CDC report. For those states, it is observed that the number of Tweets and the level of ILI activity is proportional.
# #### 3. For the states of North Dakota and Montana,  the number of Tweets and the level of ILI activity, both are minimal.
# #### 4. By analyzing the number of tweets, it can be implied that in the state of California people are appreared to be more concerned about ILI activity.
# #### 5. In a contrast, people of Louislana, Mississippi, Alabama, Georgia, South Carolina are comparatively much less active on twitter about ILI, although the ILI activity is high in those states.

# %% [markdown]
# # R Shiny App :
#
# ## App URL: https://sagnikgh-dic-lab1.shinyapps.io/FluHeatmap/

# %%
install.packages("shinyWidgets")
install.packages("shinythemes")
library(shiny)
library(shinyWidgets)
library(datasets)
library(shinythemes)

                             
   ui <- fluidPage(theme = shinytheme("superhero"),
  titlePanel("Data Intensive Computing: Lab 1: Part3"),
  
  sidebarLayout(
    sidebarPanel(
      helpText("Select Heatmap from below list"),
      
      selectInput("var", 
                  label = "Choose:",
                  choices = c("2018-19 Seasonal CDC HeatMap vs 2019 Jan 4th Weekly CDC HeatMap" = "cdc0",
                              "2018-19 Seasonal CDC HeatMap vs Twitter(#flu, #illness, #disease, #Influenza)" = "cdc1",
                              "2019 Jan 4th Week CDC HeatMap vs Twitter(#flu, #illness, #disease, #Influenza)" = "cdc2",
                              "#Influenza vs #Fluseason" = "flu1",
                             "#Flushot vs #Fluseason" = "flu2",
                             "#Flushot vs #Influenza" = "flu3"),
                  selected = "Percent White")
      ),
    
    #mainPanel(plotOutput("map"))
    mainPanel(imageOutput("myImage"))
      
      
    
  )
  )                          
                             
  server <- function(input, output) {
  output$myImage <- renderImage({

    
    switch(input$var,
           "cdc0" = list(src = 'AverageVSLastweek.png', contentType = 'image/png', width = 840, height = 840),
           "cdc1" = list(src = 'CDCvsTwitter.png', contentType = 'image/png', width = 840, height = 840),
           "cdc2" = list(src = 'CDCvsTwitter(Last Week).png', contentType = 'image/png', width = 840, height = 840),
           "flu1" = list(src = 'InfluVSseason.png', contentType = 'image/png', width = 840, height = 840),
           "flu2" = list(src = 'shotVSseason.png', contentType = 'image/png', width = 840, height = 840),
           "flu3" = list(src = 'InfluenzaVSFlushot.png', contentType = 'image/png', width = 840, height = 840)
           
    )
    
    
    
  }, deleteFile = FALSE)
  
  
  
}                           
                             
                             
                             
shinyApp(ui, server)

# %%
library("ggmap")
library("maptools")
library(maps)
library(ggplot2)
library(maptools)
register_google(key = "AIzaSyDj9GaHg6Mzh30kGImeKR5E59zQDqdVXO4")

# %%
heatmap <- read.csv("C:/Users/sagni/Box Sync/UB/Data Intensive Computing/Lab1/Part 2/data/heatmap2.csv")
heatmap1 <- read.csv("C:/Users/sagni/Box Sync/UB/Data Intensive Computing/Lab1/Part 2/data/heatmap1.csv")
heatmap2 <-  data.frame(heatmap1$STATENAME,heatmap1$ACTIVITY.LEVEL,heatmap1$ACTIVITY.LEVEL.LABEL)

# %%
heatmap2$heatmap1.ACTIVITY.LEVEL = as.numeric(substr(heatmap2$heatmap1.ACTIVITY.LEVEL,6,8))

x= aggregate(heatmap2$heatmap1.ACTIVITY.LEVEL, list(heatmap2$heatmap1.STATENAME), mean)
x[,-1] <-ceiling(x[,-1])
names(x)[names(x) == 'Group.1'] <- 'state'
names(x)[names(x) == 'x'] <- 'ACTIVITY.LEVEL'

# %%
state <- heatmap$STATENAME
activity_level <- heatmap$ACTIVITY.LEVEL
activity_level_label <- heatmap$ACTIVITY.LEVEL.LABEL
activity_weekend <- heatmap$WEEKEND
activity_season <- heatmap$WEEK
activity_week <- heatmap$SEASON

# %%
data1 <- data.frame(state,activity_level,activity_level_label)
data1$combined <- paste(data1$activity_level,data1$activity_level_label)

# %%
library(usmap)
library(ggplot2)

cols = c("Level 10 High" = "firebrick4","Level 9 High" ="firebrick1","Level 8 High" ="orange",
         "Level 7 Moderate" ="goldenrod3","Level 6 Moderate" ="yellow","Level 5 Low" ="darkolivegreen1",
         "Level 4 Low" ="darkolivegreen4","Level 3 Minimal" ="chartreuse"
         ,"Level 2 Minimal" ="chartreuse3","Level 1 Minimal" ="chartreuse4")

p2<- plot_usmap(data = x, values = "ACTIVITY.LEVEL", labels = FALSE)+
 scale_fill_continuous(name = "ILI Activity Level",low ='green',high='firebrick4') + 
  theme(legend.position = "right") + labs(title = "CDC data (Seasonal Average)", subtitle = "")

# %%
data4 <- read.csv("C:/Users/sagni/Box Sync/UB/Data Intensive Computing/Lab1/Part 2/data/StateDatabyWeekforMap_2018-19week3-4.csv")

library(usmap)
library(ggplot2)

state <- data4$STATENAME
level <- data4$ACTIVITY.LEVEL
dataframe <- data.frame(state, level)
p6 <- plot_usmap(data = dataframe, values = "level", lines = "black") + theme(legend.position = "right") + labs(title = "CSC Data (Last Week)", subtitle = "") + 
    scale_fill_manual(name = "ILI Activity Level", 
    values = c("red3","orangered1","darkorange","goldenrod3","yellow","yellow3","green","green2","green3","green4","white"), 
    lab =c("Level 10 High","Level 9 High","Level 8 High","Level 7 Moderate","Level 6 Moderate","Level 5 Low","Level 4 Low","Level 3 Minimul","Level 2 Minimul","Level 1 Minimul","Insufficient Data"))

# %%
library(gridExtra)
grid.arrange(p5, p4, ncol=2)
grid.arrange(p3, p4, ncol=2)
grid.arrange(p3, p5, ncol=2)
#<<------------------------------------------------------------------------->>#
grid.arrange(p1, p2, ncol=2)
grid.arrange(p1, p6, ncol=2)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
