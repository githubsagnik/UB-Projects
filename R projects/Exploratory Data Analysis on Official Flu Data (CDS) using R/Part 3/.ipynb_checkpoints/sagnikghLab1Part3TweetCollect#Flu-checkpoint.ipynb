# %%
## install devtools package if it's not already
#if (!requireNamespace("devtools", quietly = TRUE)) {
#  install.packages("devtools")
#}

## install dev version of rtweet from github
#devtools::install_github("mkearney/rtweet")

## load rtweet package
library(rtweet)

# %%
## access token method: create token and save it as an environment variable
twitter_token <- create_token(app = "DIC Spring - 2019",
                              consumer_key = "Iu9XwB336Rh3BlqXDfvIWw8LK",
                              consumer_secret = "RQjdRGS22Bfmg3ru462ISjC3lLoYtap6X1HoKmyTdttR1EU7V2",
                              access_token = "1098702639821451266-SH9cgv7D46of7ZhLLZiUtkfLtnTvVw",
                              access_secret = "9X04POoNBEJ4Wu1dlwKmHhQhDikKmXpvsVKUyeNADKjaL")

# %%
library(rtweet)
## authenticate via access token
#install.packages("revgeo")
library(revgeo)

# %%
## search for 1000 tweets using the flu hashtag
sinceDate <- "2019-01-01"

rt <- search_tweets("flushot" , n = 1000, include_rts = FALSE,
    geocode = lookup_coords("usa"), since = sinceDate
)
dim(rt)
# rt
#rt$location

library("ggmap")
register_google(key = "AIzaSyDj9GaHg6Mzh30kGImeKR5E59zQDqdVXO4")

geocodes <- geocode(as.character(rt$location))




tweets_collected = cbind(rt, geocodes)
tweets_path = file.path("C:", "Users", "sagni", "Box Sync", "UB","Data Intensive Computing", "Lab1", "Part 3",paste('tweets_collect_flushot', format(Sys.time(), "%d-%b-%Y"), ".csv", sep =""))
save_as_csv(tweets_collected, tweets_path)
# Out:
# [1] 175  88
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Charlotte,+NC&key=xxx
# ...

# %%
tweet_loc_data = read_twitter_csv(tweets_path, unflatten = FALSE)



tweet_state = NULL
for (row in 1:nrow(geocodes)) {
    latlong = revgeo(longitude=geocodes[row, 1], latitude=geocodes[row, 2], provider = 'photon', output='frame')
    tweet_state = rbind(tweet_state, latlong)
}


final_data = cbind(tweet_loc_data, tweet_state$state)
final_data_path = file.path("C:", "Users", "sagni", "Box Sync", "UB","Data Intensive Computing", "Lab1", "Part 3",paste('tweets_collect_states_flushot', format(Sys.time(), "%d-%b-%Y"), ".csv", sep =""))
save_as_csv(final_data, final_data_path)
# Out:
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# [1] "Getting geocode data from Photon: http://photon.komoot.de/reverse?lon=-80.8431267&lat=35.2270869"
# ...

# %%
flushotData = read.csv("C:/Users/sagni/Box Sync/UB/Data Intensive Computing/Lab1/Part 3/tweets_collect_states_flushot05-Mar-2019.csv")

# %%
flushotData
# Out:
#     user_id              status_id            created_at
# 1   x32517621            x1102809969479598081 2019-03-05 05:56:00
# 2   x32517621            x1102804016403279872 2019-03-05 05:32:21
# 3   x32517621            x1099673311989121024 2019-02-24 14:12:03
# 4   x32517621            x1099670886926422016 2019-02-24 14:02:24
# 5   x32517621            x1102271747330588672 2019-03-03 18:17:18
# 6   x32517621            x1100132084444741632 2019-02-25 20:35:03
# 7   x32517621            x1100131172993110017 2019-02-25 20:31:25
# 8   x32517621            x1099503742918017024 2019-02-24 02:58:14
# 9   x32517621            x1102263075472846849 2019-03-03 17:42:50
# 10  x32517621            x1100392663478665216 2019-02-26 13:50:29
# 11  x32517621            x1100265558401040389 2019-02-26 05:25:25
# 12  x32517621            x1102572723073679361 2019-03-04 14:13:16
# 13  x32517621            x1102273244265103360 2019-03-03 18:23:15
# ...

# %%
library(plyr)
# Out:
# Warning message:
# "package 'plyr' was built under R version 3.5.2"

# %%
flushotDataStates <-  data.frame(flushotData$tweet_state.state,flushotData$screen_name)

#flushotDataStates

finalDF = count(flushotDataStates, "flushotData.tweet_state.state")

#x[,-1] <-round(x[,-1],0)
#names(x)[names(x) == 'Group.1'] <- 'state'
#names(x)[names(x) == 'x'] <- 'ACTIVITY.LEVEL'

# %%
names(finalDF)[names(finalDF) == 'flushotData.tweet_state.state'] <- 'state'

# %%
finalDF = subset(finalDF, state!="State Not Found")
finalDF
# Out:
#    state          freq
# 1  Alabama         1
# 2  Alberta         5
# 3  Arizona         1
# 4  Arkansas        1
# 5  California     17
# 6  Colorado        1
# 7  Connecticut     3
# 8  Florida         4
# 9  Illinois        2
# 10 Iowa            1
# 11 Kansas          7
# 12 Maryland        1
# 13 Massachusetts   4
# 14 Minnesota       2
# 15 Missouri        3
# 16 Nevada          3
# 17 New Mexico      2
# 18 New York       15
# 19 North Carolina 25
# 20 Ohio            3
# 21 Ontario         3
# 22 Oregon         27
# 23 Pennsylvania    3
# 24 Rhode Island    1
# 25 South Carolina  2
# 27 Texas           9
# 28 Utah            1
# 29 Virginia        4
# 30 Washington      2
# 31 Wisconsin       1
# 32 Wyoming         1

# %%
library(usmap)
library(ggplot2)

cols = c("Level 10 High" = "firebrick4","Level 9 High" ="firebrick1","Level 8 High" ="orange",
         "Level 7 Moderate" ="goldenrod3","Level 6 Moderate" ="yellow","Level 5 Low" ="darkolivegreen1",
         "Level 4 Low" ="darkolivegreen4","Level 3 Minimal" ="chartreuse",
         "Level 2 Minimal" ="chartreuse3","Level 1 Minimal" ="chartreuse4")




plot_usmap(data = finalDF, values = "freq", labels = FALSE)+
 scale_fill_continuous(name = "Number of Tweets",low ='green',high='firebrick4') + 
  theme(legend.position = "right") + labs(title = "A Weekly Influenza Surveillance Report Prepared by the Influenza Division
Influenza-Like Illness (ILI) Activity Level Indicator Determined by Data Reported to ILINet")
# Out:
# plot without title
