# %%
import tweepy
import csv
import pandas as pd

# %%
consumer_key = 'noqE8ywLRrxE8XdLL5eEYb68l'
consumer_secret = 'INy9qcvgV6UGlSghuCes64QoUky8sEGvoWr1r5Q7dNrBoHZJYU'
access_token = '1098702639821451266-SH9cgv7D46of7ZhLLZiUtkfLtnTvVw'
access_token_secret = '9X04POoNBEJ4Wu1dlwKmHhQhDikKmXpvsVKUyeNADKjaL'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

csvFile = open('tweets_collected.csv', 'a')

csvWriter = csv.writer(csvFile)
query = {"#flu", "#illness", "#disease", "#Influenza"}

for q in query:

	for tweet in tweepy.Cursor(api.search, q, count=100,lang="en", since="2018-11-01").items():
	    print (tweet.created_at, tweet.text)
	    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# 2019-02-21 22:49:08 RT @Kim_Wyrt: #Flu? Try this recommendation for a champagne cocktail form the Chemist + Druggist, 1935. I adore the @WellcomeLibrary for di…
# 2019-02-21 22:48:21 RT @CDCgov: New CDC study shows flu vaccine prevented more than 7 million flu illnesses, 109,000 flu hospitalizations &amp; 8,000 flu deaths du…
# 2019-02-21 22:47:58 RT @CDCgov: New CDC study shows flu vaccine prevented more than 7 million flu illnesses, 109,000 flu hospitalizations &amp; 8,000 flu deaths du…
# 2019-02-21 22:47:33 RT @CDCgov: New CDC study shows flu vaccine prevented more than 7 million flu illnesses, 109,000 flu hospitalizations &amp; 8,000 flu deaths du…
# 2019-02-21 22:46:56 RT @CDCgov: New CDC study shows flu vaccine prevented more than 7 million flu illnesses, 109,000 flu hospitalizations &amp; 8,000 flu deaths du…
# 2019-02-21 22:46:17 RT @CDCgov: New CDC study shows flu vaccine prevented more than 7 million flu illnesses, 109,000 flu hospitalizations &amp; 8,000 flu deaths du…
# ...
