# %% [markdown]
# ### Sagnik Ghosh
# ### UbitName : sagnikgh
# ### Person Number : 50289151

# %% [markdown]
# ### Teammate :
# ### Apurba Mahanta
# ### UbitName : apurbama
# ### Person Number : 50288705

# %%
import tweepy
import csv
import pandas as pd

consumer_key = 'iLXYtbmUlgGqmervwtYF9GKsf'
consumer_secret = 'MKOtO6DJP5y6njn5EWb1KEp3sloIx2f39IIyeOXgwOOtfeH5Ad'
access_token = '1098682173316624384-ttp4l1J62DiIQ4T0hWh5lesbNN4BIx'
access_token_secret = 'KYdBeddOk3pCwDptACqYyTKwVkpDodgZ3KhTY6cO4QQNr'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

csvFile = open('tweets_collected_0307_influenza.csv', 'a')

csvWriter = csv.writer(csvFile,delimiter=',')
query = {"#flu", "#illness", "#disease", "#Influenza"}
#query = {"#Influenza"}
#USA geocode ="39.8,-95.583068847656,2500km"
for q in query:
    for tweet in tweepy.Cursor(api.search, q, count=100,lang="en", since="2019-01-01"
                               ,geocode="39.8,-95.583068847656,2500km").items():
        if ((not tweet.retweeted) and ('RT' not in tweet.text)):
            print (tweet.created_at,tweet.id, tweet.text,tweet.user.location, tweet.coordinates)
            csvWriter.writerow([tweet.created_at,tweet.id, tweet.text.encode('utf-8'),tweet.user.location])
# Out:
# 2019-03-07 16:45:18 1103698146855534593 I was driving to work this morning, and I almost caught a cold. Unfortunately, I couldn't accelerate fast enough. T… https://t.co/mxwTceoOGW San Diego, CA None
# 2019-03-07 15:45:05 1103682993615454217 Check out the March Issue of the International Journal of Infectious Diseases #IJID #openaccess #hepatitis… https://t.co/MIcZtAoKNh Boston, MA None
# 2019-03-07 15:07:22 1103673499107905536 Mayo Clinic Minute: The Flu Season Is Not Over And It's Not Too Late To Get A Flu Shot #Influenza #FluShot https://t.co/izCBIxKTd6 Boston, MA, USA None
# 2019-03-07 14:40:40 1103666780533284864 Getting a flu shot while hospitalized lowers the chance of a heart attack https://t.co/vF2bsNC2pu via… https://t.co/rn2egfCjFX Edmonton, Canada None
# 2019-03-07 13:30:39 1103649162950782976 Did you know that children, pregnant women, adults 65 and older, and people with medical conditions have higher ris… https://t.co/gMWgfYCyAR Tallahassee, FL None
# ...
